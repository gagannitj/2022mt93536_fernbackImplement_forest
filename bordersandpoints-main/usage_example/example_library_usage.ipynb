# %% [markdown]
# # Installing required

# %%
# !pip install -U git+https://github.com/luca-medeiros/lang-segment-anything.git

# %%
# !pip install bordersandpoints

# %% [markdown]
# # Importing functions from library

# %%
from bordersandpoints import border_lines_cap,create_video,process_video

# %% [markdown]
# # Getting video with point which present in the entire video, obtained using farneback algorithm

# %%
import os
video_file = ["1710074366570.mp4"]
video_path = "/kaggle/input/check-check"
os.mkdir("/kaggle/working/testing")
output_path = "/kaggle/working/testing"
initial_point=(500, 600)
process_video(video_file,video_path,output_path,initial_point) #function to get video with point which is present in the entire video

# %% [markdown]
# # Getting border lines for every frame in the video

# %%
lines_output = "/kaggle/working/testing/videos"
os.mkdir(lines_output)
border_lines_cap(video_file,output_path, lines_output) #function to get video frames with border lines

# %% [markdown]
# # Obtaining video from video frames

# %%
create_video("/kaggle/working/testing/videos/1710074366570","/kaggle/working/1710074366570_borders_point.mp4") #function to create video from frames
